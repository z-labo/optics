# %% [markdown]
# # Coupled-Wave Equations
#
# > **出典.** このノートは、**Friedrich Schiller University Jena** において **2021/22年冬学期**に **Prof. G. G. Paulus** が担当した **Nonlinear Optics** の講義資料です。
#
# 導出の順序、記号、および式番号は提供された講義ノートに従っています。数式は Jupyter Notebook で読みやすいように LaTeX 形式へ整形しています。

# %% [markdown]
# ## 非線形光学媒質における波動方程式
#
# ### Maxwell 方程式から一般的な波動方程式を導く
#
# Ampère の法則を Faraday の法則に代入する形で波動方程式を導出する。
#
# $$
# \vec{\nabla}\times\vec{\nabla}\times\widetilde{\vec E}
# =
# -\mu_0\partial_t^2\widetilde{\vec D}
# $$
#
# $$
# \widetilde{\vec D}
# =
# \varepsilon_0\widetilde{\vec E}
# +
# \widetilde{\vec P},
# \qquad
# \mu_0=\frac{1}{\varepsilon_0c^2}
# $$
#
# $$
# \vec{\nabla}\times\vec{\nabla}\times\widetilde{\vec E}
# +
# \frac{1}{c^2}\partial_t^2\widetilde{\vec E}
# =
# -\frac{1}{\varepsilon_0c^2}\partial_t^2\widetilde{\vec P}
# \tag{5}
# $$
#
#
# 式 (5) は、ここで用いる古典非線形光学における最も一般的な波動方程式の形である。
#
#
# ### 平面波条件と分極の線形・非線形成分への分離
#
# 光学では
# $\vec{\nabla}\times\vec{\nabla}\times\widetilde{\vec E}$
# を Laplacian に置き換えたい。しかし一般には電場の発散は 0 ではない。平面波について
#
# $$
# \nabla\cdot\vec E=0
# $$
#
# を用いると、
#
# $$
# -\nabla^2\widetilde{\vec E}
# +
# \frac{1}{c^2}\partial_t^2\widetilde{\vec E}
# =
# -\frac{1}{\varepsilon_0c^2}\partial_t^2\widetilde{\vec P}
# \tag{6}
# $$
#
# $$
# \widetilde{\vec P}
# =
# \widetilde{\vec P}^{(1)}
# +
# \widetilde{\vec P}^{NL}
# \tag{7}
# $$
#
# $$
# -\nabla^2\widetilde{\vec E}
# +
# \frac{1}{c^2}\partial_t^2
# \left(
# \widetilde{\vec E}
# +
# \frac{1}{\varepsilon_0}\widetilde{\vec P}^{(1)}
# \right)
# =
# -\frac{1}{\varepsilon_0c^2}
# \partial_t^2\widetilde{\vec P}^{NL}
# \tag{8}
# $$
#
# ここで
#
# $$
# \widetilde{\vec D}^{(1)}
# =
# \varepsilon_0\widetilde{\vec E}
# +
# \widetilde{\vec P}^{(1)},
# $$
#
# を用いると
#
# $$
# -\nabla^2\widetilde{\vec E}
# +
# \frac{1}{\varepsilon_0c^2}
# \partial_t^2\widetilde{\vec D}^{(1)}
# =
# -\frac{1}{\varepsilon_0c^2}
# \partial_t^2\widetilde{\vec P}^{NL}.
# \tag{9}
# $$
#
# ### 単純な場合：無損失・無分散媒質
#
# 無損失かつ無分散の媒質では、線形応答が瞬時応答であると仮定する。
#
# $$
# \widetilde{\vec D}^{(1)}(t)
# =
# \varepsilon_0\varepsilon\,
# \widetilde{\vec E}(t)
# \tag{10}
# $$
#
# 式 (10) を式 (9) に代入すると、
#
# $$
# -\nabla^2\widetilde{\vec E}
# +
# \frac{\varepsilon^{(1)}}{c^2}
# \partial_t^2\widetilde{\vec E}
# =
# -\frac{1}{\varepsilon_0c^2}
# \partial_t^2\widetilde{\vec P}^{NL}.
# \tag{11}
# $$
#
# 一般には、
#
# $$
# D(t)\neq E(t),
# \qquad
# D(\omega)\sim E(\omega).
# $$
#
#
# 式 (11) は、右辺の非線形分極項をソース項とする波動方程式である。
#
# ### 一般の場合：分散媒質と単色波成分
#
# 分散媒質では、時間領域において式 (10) は成立しない。しかし周波数領域では、線形電気変位と電場は周波数依存の誘電応答によって関係づけられる。
#
# 2次の非線形過程では3つの波が結合し、3次の過程では4つの波が結合する。実際に結合する波は少数なので、全電場を単色波成分の和として表すことができる。
#
# $$
# \widetilde{\vec D}^{(1)}(\omega)
# =
# \varepsilon_0\varepsilon^{(1)}(\omega)
# \widetilde{\vec E}(\omega)
# $$
#
# $$
# \widetilde{\vec E}(\vec r,t)
# =
# \sum_n' \widetilde{\vec E}_n(\vec r,t)
# $$
#
# $$
# \widetilde{\vec D}(\vec r,t)
# =
# \sum_n' \widetilde{\vec D}_n(\vec r,t)
# $$
#
# $$
# \widetilde{\vec P}^{NL}(\vec r,t)
# =
# \sum_n' \widetilde{\vec P}^{NL}_n(\vec r,t)
# \tag{13}
# $$
#
# ここで
#
# $\varepsilon^{(1)}\in\mathbb{R}$ と仮定し、周波数成分を式 (9) に代入すると、
#
# $$
# -\nabla^2\widetilde{\vec E}_n
# +
# \frac{\varepsilon^{(1)}(\omega_n)}{c^2}
# \partial_t^2\widetilde{\vec E}_n
# =
# -\frac{1}{\varepsilon_0c^2}
# \partial_t^2\widetilde{\vec P}^{NL}_n.
# \tag{15}
# $$
#
# 単色波について、
#
# $$
# \widetilde{\vec E}_n(\vec r,t)
# =
# \vec E_n(\vec r)e^{-i\omega_nt}
# +c.c.,
# \qquad
# \vec E_n\in\mathbb C^3,
# $$
#
# $$
# \widetilde{\vec D}_n(\vec r,t)
# =
# \vec D_n(\vec r)e^{-i\omega_nt}
# +c.c.,
# \qquad
# \vec D_n\in\mathbb C^3,
# $$
#
# $$
# \widetilde{\vec P}_n(\vec r,t)
# =
# \vec P_n(\vec r)e^{-i\omega_nt}
# +c.c.,
# \qquad
# \vec P_n\in\mathbb C^3.
# \tag{16}
# $$
#
# 空間依存性と時間依存性を分離したので、
#
# $$
# \partial_t^2\sim-\omega^2,
# $$
#
# したがって
#
# $$
# \nabla^2\widetilde{\vec E}_n(\vec r)
# +
# \frac{\varepsilon^{(1)}(\omega_n)\omega_n^2}{c^2}
# \widetilde{\vec E}_n
# =
# -\frac{\omega_n^2}{\varepsilon_0c^2}
# \widetilde{\vec P}^{NL}_n.
# \tag{17}
# $$
#
#
# 式 (15) は式 (11) と同じ代数的な形を持ち、物質応答が周波数に依存する場合にも適用できる。

# %% [markdown]
# ## 和周波発生 (SFG) の結合波方程式
#
# ### 場の方程式と緩やかに変化する振幅の Ansatz
#
# ここでは、前節の波動方程式を具体的な非線形相互作用である和周波発生（SFG）に適用する。
#
# SFG では、
# $$
# \omega_3=\omega_1+\omega_2.
# $$
#
# 式 (15) の $\omega_3$ 成分は次のようになる。
#
# $$
# -\nabla^2\widetilde{\vec E}_3
# +
# \frac{n_3^2}{c^2}
# \partial_t^2\widetilde{\vec E}_3
# =
# -\frac{1}{\varepsilon_0c^2}
# \partial_t^2\widetilde{\vec P}^{NL}_3.
# \tag{20}
# $$
#
# 右辺が無視できるほど小さい場合、通常の波動方程式の解は
#
# $$
# \widetilde E_3(z,t)
# =
# A_3e^{i(k_3z-\omega_3t)}
# +c.c.,
# $$
#
# $$
# k_3=\frac{n_3\omega_3}{c}.
# \tag{21}
# $$
#
# 非線形ソースが小さいが 0 ではない場合、次の Ansatz を用いる。
#
# $$
# \widetilde E_3(z,t)
# =
# A_3(z)e^{i(k_3z-\omega_3t)}
# +c.c.
# $$
#
#
# 結晶中を伝搬するにつれて生成波の振幅 $A_3(z)$ が成長すると期待されるため、振幅を $z$ の関数とするのは物理的に自然である。

# %% [markdown]
# ### 非線形ソース分極
#
# 非線形ソース項を次のように書く。
#
# $$
# \widetilde P_3(z,t)
# =
# P_3(z)e^{-i\omega_3t}
# +c.c.,
# $$
#
# $$
# P_3
# =
# 4\varepsilon_0d_{\mathrm{eff}}E_1E_2,
# \qquad
# 2d_{\mathrm{eff}}\sim\chi^{(2)}.
# \tag{24}
# $$
#
# また、
#
# $$
# E_i(z,t)
# =
# E_ie^{-i\omega_it}+c.c.,
# \qquad
# E_i=A_ie^{ik_iz}.
# \tag{25}
# $$
#
# したがって、
#
# $$
# P_3
# =
# 4\varepsilon_0d_{\mathrm{eff}}
# A_1A_2e^{i(k_1+k_2)z}.
# \tag{26}
# $$

# %% [markdown]
# ### 波動方程式への代入
#
# 場の Ansatz と式 (26) を式 (20) に代入する。
#
# 第1項：
#
# $$
# -\nabla^2\widetilde{\vec E}_3
# =
# -\partial_z^2
# \left[
# A_3(z)e^{i(k_3z-\omega_3t)}+c.c.
# \right]
# $$
#
# $$
# =
# -
# \left[
# \frac{\partial^2A_3}{\partial z^2}
# +
# 2ik_3\frac{\partial A_3}{\partial z}
# -
# k_3^2A_3
# \right]
# e^{i(k_3z-\omega_3t)}
# +c.c.
# $$
#
# 第2項：
#
# $$
# \frac{n_3^2}{c^2}\partial_t^2\widetilde{\vec E}_3
# =
# -\frac{n_3^2\omega_3^2}{c^2}
# \left[
# A_3e^{i(k_3z-\omega_3t)}+c.c.
# \right].
# $$
#
# 第3項：
#
# $$
# -\frac{1}{\varepsilon_0c^2}
# \partial_t^2\widetilde{\vec P}^{NL}_3
# =
# \frac{4\varepsilon_0d_{\mathrm{eff}}\omega_3^2}
# {\varepsilon_0c^2}
# A_1A_2
# e^{i[(k_1+k_2)z-\omega_3t]}
# +c.c.
# $$

# %% [markdown]
# ### 各項をまとめる
#
# 各項をまとめると、
#
# $$
# \left[
# -\frac{\partial^2A_3}{\partial z^2}
# -2ik_3\frac{\partial A_3}{\partial z}
# +k_3^2A_3
# -\frac{n_3^2\omega_3^2}{c^2}A_3
# \right]
# e^{i(k_3z-\omega_3t)}
# +c.c.
# =
# \frac{4\varepsilon_0d_{\mathrm{eff}}\omega_3^2}
# {\varepsilon_0c^2}
# A_1A_2
# e^{i[(k_1+k_2)z-\omega_3t]}
# +c.c.
# $$
#
# ここで
#
# $$
# k_3^2A_3-\frac{n_3^2\omega_3^2}{c^2}A_3=0,
# $$
# であり、さらに $e^{-i\omega t}$ と $e^{i\omega t}$ は線形独立なので、$c.c.$ 項は別々に扱うことができる。 $e^{-i\omega_3t}$ で割ると
# $$
# -
# \left[
# \frac{\partial^2A_3}{\partial z^2}
# +
# 2ik_3\frac{\partial A_3}{\partial z}
# \right]
# e^{ik_3z}
# =
# \frac{4\varepsilon_0d_{\mathrm{eff}}\omega_3^2}
# {\varepsilon_0c^2}
# A_1A_2e^{i(k_1+k_2)z}.
# \tag{27}
# $$

# %% [markdown]
# ### 緩変振幅近似 (SVAA)
#
# 緩変振幅近似（SVAA）では、振幅の2階空間微分を無視する：
#
# $$
# \frac{\partial^2A_3}{\partial z^2}
# \ll
# k_3\frac{\partial A_3}{\partial z}.
# $$
#
# すると
#
# $$
# -2ik_3\frac{\partial A_3}{\partial z}e^{ik_3z}
# =
# \frac{4\varepsilon_0d_{\mathrm{eff}}\omega_3^2}
# {\varepsilon_0c^2}
# A_1A_2e^{i(k_1+k_2)z},
# $$
#
# したがって
#
# $$
# \frac{\partial A_3}{\partial z}
# =
# i\frac{2d_{\mathrm{eff}}\omega_3^2}{k_3c^2}
# A_1A_2e^{i(k_1+k_2-k_3)z}.
# $$
#
# 次のように定義する：
#
# $$
# \Delta k=k_1+k_2-k_3,
# \qquad
# k_3=\frac{n_3\omega_3}{c}.
# $$
#
# 従って、
#
# $$
# \frac{\partial A_3}{\partial z}
# =
# i\frac{2d_{\mathrm{eff}}\omega_3}{n_3c}
# A_1A_2e^{i\Delta kz}.
# \tag{28}
# $$

# %% [markdown]
# ### 3つの波すべてに対する結合方程式
#
# 同じ手順を $A_1$ および $A_2$ にも適用する。次の関係を用いる：
#
# $$
# \omega_1=\omega_3-\omega_2,
# \qquad
# \omega_2=\omega_3-\omega_1.
# $$
#
# 非線形分極は
#
# $$
# P_1
# =
# 4\varepsilon_0d_{\mathrm{eff}}
# A_3A_2^*e^{i(k_3-k_2)z},
# $$
#
# $$
# P_2
# =
# 4\varepsilon_0d_{\mathrm{eff}}
# A_3A_1^*e^{i(k_3-k_1)z}.
# $$
#
# したがって、
#
# <div style="border: 4px solid; padding: 18px 24px; margin: 20px 0; border-radius: 6px;">
#
# $$
# \begin{aligned}
# \frac{\partial A_1}{\partial z}
# &=
# i\frac{2d_{\mathrm{eff}}\omega_1^2}{k_1c^2}
# A_3(z)A_2^*(z)e^{-i\Delta kz},
# \\[8pt]
# \frac{\partial A_2}{\partial z}
# &=
# i\frac{2d_{\mathrm{eff}}\omega_2^2}{k_2c^2}
# A_3(z)A_1^*(z)e^{-i\Delta kz},
# \\[8pt]
# \frac{\partial A_3}{\partial z}
# &=
# i\frac{2d_{\mathrm{eff}}\omega_3^2}{k_3c^2}
# A_1(z)A_2(z)e^{i\Delta kz}.
# \end{aligned}
# $$
#
# </div>

# %% [markdown]
# ## 位相整合と位相不整合 (Phase (Mis)match Considerations)
#
# ### ポンプ枯渇を無視する近似
#
# $A_3$ が $A_1$、$A_2$ に比べて十分小さいと仮定する。したがって、$A_1$ と $A_2$ は $z$ に依存しないものとする：
#
# $$
# \frac{\partial A_3}{\partial z}
# =
# i\frac{2d_{\mathrm{eff}}\omega_3^2}{k_3c^2}
# A_1A_2e^{i\Delta kz}.
# $$
#
# ### 完全な位相整合：$\Delta k=0$
#
# さらに簡単化するため、完全な位相整合を仮定する：
#
# $$
# \Delta k=0.
# $$
#
# この場合、$A_3(z)$ は $z$ に対して線形に増加する。したがって、強度 $I_3(z)$ は $z$ の二乗に比例して増加する：
#
# $$
# A_3(z)\propto z,
# \qquad
# I_3(z)\propto z^2.
# $$
#
# ### 位相不整合：$\Delta k\neq0$
#
# 次に、
#
# $$
# \Delta k\neq0
# $$
#
# の場合を考える。
#
# $z=0$ から $z=L$ まで積分すると、
#
# $$
# A_3(L)
# =
# i\frac{2d_{\mathrm{eff}}\omega_3^2}{k_3c^2}
# A_1A_2
# \int_0^L e^{i\Delta kz}\,dz,
# $$
#
# したがって、
#
# $$
# A_3(L)
# =
# i\frac{2d_{\mathrm{eff}}\omega_3^2}{k_3c^2}
# A_1A_2
# \frac{e^{i\Delta kL}-1}{i\Delta k}.
# $$
#
# ### 生成波の強度
#
# $\Delta k\neq0$ の影響を見るため、$I_3$ を計算する：
#
# $$
# I_3
# =
# \frac{cn_3\varepsilon_0}{2}|A_3|^2
# =
# \frac{2\varepsilon_0d_{\mathrm{eff}}^2\omega_3^2}{n_3c^2}
# |A_1|^2|A_2|^2
# \left|
# \frac{e^{i\Delta kL}-1}{\Delta k}
# \right|^2.
# $$
#
# また、
#
# $$
# c\varepsilon_0=\frac{1}{377\ \Omega}.
# $$
#
# ### Sinc 関数による位相不整合の効果
#
# 次を用いると、
#
# $$
# \left|
# \frac{e^{i\Delta kL}-1}{\Delta k}
# \right|^2
# =
# L^2
# \operatorname{sinc}^2
# \left(\frac{\Delta kL}{2}\right),
# $$
#
# 位相不整合による変換効率の変化は $\operatorname{sinc}^2$ 関数で表される。
#
# ### $I_1$ と $I_2$ を用いた表現
#
# 次を用いる：
#
# $$
# I_1=\frac{cn_1\varepsilon_0}{2}|A_1|^2,
# \qquad
# I_2=\frac{cn_2\varepsilon_0}{2}|A_2|^2.
# $$
#
# すると、
#
# <div style="border: 4px solid; padding: 18px 24px; margin: 20px 0; border-radius: 6px;">
#
# $$
# I_3
# =
# 8
# \frac{
# d_{\mathrm{eff}}^2\omega_3^2 I_1 I_2
# }{
# n_1n_2n_3\varepsilon_0c^3
# }
# L^2
# \operatorname{sinc}^2
# \left(
# \frac{\Delta kL}{2}
# \right).
# $$
#
# </div>
#
# 提供された講義ノートの表記に従うと、
#
# $$
# L\equiv L_{\mathrm{coh}}=\frac{2}{\Delta k}.
# $$
